# %%
import pandas as pd

# %%
df = pd.read_csv('./data/associative_words.csv', index_col=0)
df.head()
# Out:
#   first_keyword second_keyword associative_word
# 0            あお      あおばのはなのあと          かかるふじなみ
# 1            あお           あおやぎ           かつらぎやま
# 2            あお        あおやぎのいと       うちはえる-かわぞい
# 3            あお        あおやぎのかげ            はなをみる
# 4            あお        なびくあおやぎ          かすむ-のこる

# %%
first_keywords = df['first_keyword'].unique().tolist()
second_keywords = df['second_keyword'].unique().tolist()

# %%
first_keywords
# Out:
# ['あお',
#  'あかしがた',
#  'あかつき',
#  'あき',
#  'あけぼの',
#  'あける',
#  'あさ',
#  'あさがお',
#  'あさの',
#  'あし',
#  'あじけない',
#  'あだ',
#  'あと',
#  'あま',
#  'あまた',
#  'あまひこ',
#  'あめ',
#  'あやめぐさ',
#  'あゆ',
#  'あらし',
#  'あらそう',
#  'あらまし',
#  'あらわれる',
#  'ありあけ',
#  'ある',
#  'あわれ',
#  'い',
#  'いかが',
#  'いくえ',
#  'いけ',
#  'いさらい',
#  'いずち',
#  'いそぐ',
#  'いち',
#  'いつ',
#  'いつわり',
#  'いと',
#  'いとう',
#  'いなおおせどり',
#  'いなずま',
#  'いにしえ',
#  'いのち',
#  'いのる',
#  'いま',
#  'いも',
#  'いりあい',
#  'いろ',
#  'いろいろ',
#  'いわ',
#  'いわう',
#  'うい',
#  'うえ',
#  'うえる',
#  'うぐいす',
#  'うける',
#  'うた',
#  'うち',
#  'うつ',
#  'うつのやま',
#  'うのはな',
#  'うみ',
#  'うめ',
#  'うら',
#  'うらむ',
#  'えだ',
#  'おい',
#  'おうさかのせき',
#  'おうさかのやま',
#  'おおはら',
#  'おか',
#  'おき',
#  'おぎ',
#  'おく',
#  'おくる',
#  'おぐるま',
#  'おしい',
#  'おだまき',
#  'おちこち',
#  'おちる',
#  'おと',
#  'おとめ',
#  'おとろえる',
#  'おとわやま',
#  'おなじ',
#  'おのえ',
#  'おぶね',
#  'おぼえる',
#  'おぼろ',
#  'おみなえし',
#  'おもい',
#  'おもう',
#  'おもかげ',
#  'おりおり',
#  'おろか',
#  'か',
#  'かえす',
#  'かえる',
#  'かかる',
# ...

# %%
df[df['first_keyword'] == 'うぐいす']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-8dcd1ac6f207> in <module>
# ----> 1 df[df['first_keyword'] == 'うぐいす']
#
# NameError: name 'df' is not defined

# %%
kigo_df = pd.read_csv('./data/kigo.csv', index_col=0)
kigo_df.head()
# Out:
#   季節    季語    読み仮名   傍題
# 0  春   藍蒔く    あいまく  藍植う
# 1  春  青木の花  あおきのはな  花青木
# 2  春    石蓴     あおさ   川菜
# 3  春    青饅    あおぬた  NaN
# 4  春    青麦    あおむぎ  麦青む

# %%
kigo_df[kigo_df['読み仮名'] == 'うぐいす']
# Out:
#    季節 季語  読み仮名                     傍題
# 45  春  鶯  うぐいす  黄鳥・匂鳥・春告鳥・初音・鶯の谷渡り・鶯笛

# %%
a = [('春', 'あいまく')]
a
# Out:
# [('春', 'あいまく')]

# %%
set(map(lambda x: x[0], a)).pop()
# Out:
# '春'

# %%
', '.join(list(map(lambda x: x[1], a)))
# Out:
# 'あいまく'

# %%
len('')
# Out:
# 0
